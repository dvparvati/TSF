# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('//Users/Parvati/Downloads/globalterrordata.csv')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
list(df.columns)
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
df.rename(columns={'country_txt':'Country','region_txt':'Region','attacktype1_txt':'Attack_type','target1':'Target',
                   'nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                   'weaptype1_txt':'Weapon_type','success':'Success','motive':'Motive'}, inplace=True)

# %%
list(df.columns)
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'Country',
#  'region',
#  'Region',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'Summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'Success',
#  'suicide',
#  'attacktype1',
#  'Attack_type',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'Target_type',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'Target',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'Group',
#  'gsubname',
#  'gname2',
#  'gsubname2',
#  'gname3',
# ...

# %%
new_col=df[['iyear','Country','Region','city','latitude','longitude','location','Attack_type','Killed','Wounded','Group','Weapon_type','claimed','Target','Success','nwoundus','nkillus','nkillter','weapdetail','Motive','suicide']]

# %%
new_col.head()
# Out:
#    iyear             Country                       Region           city  \
# 0   1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1   1970              Mexico                North America    Mexico city
# 2   1970         Philippines               Southeast Asia        Unknown
# 3   1970              Greece               Western Europe         Athens
# 4   1970               Japan                    East Asia        Fukouka
#
#     latitude   longitude location                     Attack_type  Killed  \
# 0  18.456792  -69.951164      NaN                   Assassination     1.0
# 1  19.371887  -99.086624      NaN     Hostage Taking (Kidnapping)     0.0
# 2  15.478598  120.599741      NaN                   Assassination     1.0
# 3  37.997490   23.762728      NaN               Bombing/Explosion     NaN
# 4  33.580412  130.396361      NaN  Facility/Infrastructure Attack     NaN
#
#    Wounded  ... Weapon_type claimed                   Target Success  \
# ...

# %%
new_col["Killed"]=new_col["Killed"].fillna(0)
new_col["Wounded"]=new_col["Wounded"].fillna(0)
new_col["Casualty"]=new_col["Killed"] + new_col["Wounded"]

# %%
new_col.head()
# Out:
#    iyear             Country                       Region           city  \
# 0   1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1   1970              Mexico                North America    Mexico city
# 2   1970         Philippines               Southeast Asia        Unknown
# 3   1970              Greece               Western Europe         Athens
# 4   1970               Japan                    East Asia        Fukouka
#
#     latitude   longitude location                     Attack_type  Killed  \
# 0  18.456792  -69.951164      NaN                   Assassination     1.0
# 1  19.371887  -99.086624      NaN     Hostage Taking (Kidnapping)     0.0
# 2  15.478598  120.599741      NaN                   Assassination     1.0
# 3  37.997490   23.762728      NaN               Bombing/Explosion     0.0
# 4  33.580412  130.396361      NaN  Facility/Infrastructure Attack     0.0
#
#    Wounded  ... claimed                   Target  Success nwoundus  nkillus  \
# ...

# %%
new_col.duplicated().sum()
# Out:
# 10750

# %%
new_col.drop_duplicates(inplace = True)

# %%
new_col.duplicated().sum()
# Out:
# 0

# %%
new_col.head()
# Out:
#    iyear             Country                       Region           city  \
# 0   1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1   1970              Mexico                North America    Mexico city
# 2   1970         Philippines               Southeast Asia        Unknown
# 3   1970              Greece               Western Europe         Athens
# 4   1970               Japan                    East Asia        Fukouka
#
#     latitude   longitude location                     Attack_type  Killed  \
# 0  18.456792  -69.951164      NaN                   Assassination     1.0
# 1  19.371887  -99.086624      NaN     Hostage Taking (Kidnapping)     0.0
# 2  15.478598  120.599741      NaN                   Assassination     1.0
# 3  37.997490   23.762728      NaN               Bombing/Explosion     0.0
# 4  33.580412  130.396361      NaN  Facility/Infrastructure Attack     0.0
#
#    Wounded  ... claimed                   Target  Success nwoundus  nkillus  \
# ...

# %%
new_col.fillna('')
# Out:
#         iyear             Country                       Region           city  \
# 0        1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1        1970              Mexico                North America    Mexico city
# 2        1970         Philippines               Southeast Asia        Unknown
# 3        1970              Greece               Western Europe         Athens
# 4        1970               Japan                    East Asia        Fukouka
# ...       ...                 ...                          ...            ...
# 181686   2017             Somalia           Sub-Saharan Africa  Ceelka Geelow
# 181687   2017               Syria   Middle East & North Africa         Jableh
# 181688   2017         Philippines               Southeast Asia       Kubentog
# 181689   2017               India                   South Asia         Imphal
# 181690   2017         Philippines               Southeast Asia  Cotabato City
#
#          latitude   longitude  \
# ...

# %%
new_col.describe()
# Out:
#                iyear       latitude     longitude         Killed  \
# count  170941.000000  166955.000000  1.669540e+05  170941.000000
# mean     2003.060454      23.785280 -4.866105e+02       2.383975
# std        13.187187      18.286682  2.109298e+05      11.550155
# min      1970.000000     -53.154613 -8.618590e+07       0.000000
# 25%      1991.000000      11.840929  7.446043e+00       0.000000
# 50%      2009.000000      31.528200  4.353553e+01       0.000000
# 75%      2014.000000      34.674866  6.901556e+01       2.000000
# max      2017.000000      74.633553  1.793667e+02    1570.000000
#
#              Wounded        claimed        Success       nwoundus  \
# count  170941.000000  112365.000000  170941.000000  113615.000000
# mean        3.036796       0.049241       0.888693       0.040030
# std        35.357878       1.096272       0.314513       3.102349
# min         0.000000      -9.000000       0.000000       0.000000
# ...

# %%
new_col.shape
# Out:
# (170941, 22)

# %%
new_col.to_csv('golter_data.csv')
